# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.tail(10)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101756     443842070    140199494            Other  Female  [60-70)      ?
# 101757     443842136    181593374        Caucasian  Female  [70-80)      ?
# 101758     443842340    120975314        Caucasian  Female  [80-90)      ?
# 101759     443842778     86472243        Caucasian    Male  [80-90)      ?
# 101760     443847176     50375628  AfricanAmerican  Female  [60-70)      ?
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
# prompt: how many Caucasian Male, age 70-80

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# Filter for Caucasian Male patients aged 70-80
filtered_df = df[(df['race'] == 'Caucasian') & (df['gender'] == 'Male') & (df['age'] == '[70-80)')]

# Count the number of patients in the filtered DataFrame
count = len(filtered_df)

print(f"Number of Caucasian Male patients aged 70-80: {count}")
# Out:
# Number of Caucasian Male patients aged 70-80: 10007

# %%
filtered_df = df[(df['race'] == 'Caucasian') & (df['gender'] == 'Female') & (df['age'] == '[70-80)')]
count = len(filtered_df)
print(f"Number of Caucasian Female patients aged 70-80: {count}")
# Out:
# Number of Caucasian Female patients aged 70-80: 10754

# %%
filtered_df = df[(df['race'] == 'Caucasian') & (df['gender'] == 'Female') & (df['age'] == '[70-80)') & (df['insulin'] == 'Steady')]
count = len(filtered_df)
print(f"Number of Caucasian Female patients aged 70-80 with steady insulin: {count}")
# Out:
# Number of Caucasian Female patients aged 70-80 with steady insulin: 3128

# %%
filtered_df = df[(df['race'] == 'Caucasian') & (df['gender'] == 'Male') & (df['age'] == '[70-80)') & (df['insulin'] == 'Steady')]
count = len(filtered_df)
print(f"Number of Caucasian Female patients aged 70-80 with steady insulin: {count}")
# Out:
# Number of Caucasian Female patients aged 70-80 with steady insulin: 2857

# %%
df[['encounter_id', 'race', 'gender', 'age', 'insulin']].head(10)
# Out:
#    encounter_id             race  gender       age insulin
# 0       2278392        Caucasian  Female    [0-10)      No
# 1        149190        Caucasian  Female   [10-20)      Up
# 2         64410  AfricanAmerican  Female   [20-30)      No
# 3        500364        Caucasian    Male   [30-40)      Up
# 4         16680        Caucasian    Male   [40-50)  Steady
# 5         35754        Caucasian    Male   [50-60)  Steady
# 6         55842        Caucasian    Male   [60-70)  Steady
# 7         63768        Caucasian    Male   [70-80)      No
# 8         12522        Caucasian  Female   [80-90)  Steady
# 9         15738        Caucasian  Female  [90-100)  Steady

# %%
df[['encounter_id', 'race', 'gender', 'age', 'insulin']]
value_counts = df['insulin'].value_counts(), df['race'].value_counts(), df['gender'].value_counts(), df['age'].value_counts()
print(value_counts)
# Out:
# (insulin
# No        47383
# Steady    30849
# Down      12218
# Up        11316
# Name: count, dtype: int64, race
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: count, dtype: int64, gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: count, dtype: int64, age
# [70-80)     26068
# [60-70)     22483
# [50-60)     17256
# [80-90)     17197
# [40-50)      9685
# [30-40)      3775
# [90-100)     2793
# [20-30)      1657
# [10-20)       691
# [0-10)        161
# Name: count, dtype: int64)

# %%
# prompt: create a table comparing the count of Caucasian males and females, age 70-80 with Steady insulin

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# Filter for Caucasian patients aged 70-80 with Steady insulin
filtered_df = df[(df['race'] == 'Caucasian') & (df['age'] == '[70-80)') & (df['insulin'] == 'Steady')]

# Create a table comparing the count of males and females
table = pd.pivot_table(filtered_df, values='encounter_id', index=['gender'], aggfunc='count')

table
# Out:
#         encounter_id
# gender
# Female          3128
# Male            2857
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# table['encounter_id'].plot(kind='hist', bins=20, title='encounter_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# table['encounter_id'].plot(kind='line', figsize=(8, 4), title='encounter_id')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# prompt: plot scatter all the Caucasian males and females, age 70-80 with Steady insulin

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# Filter for Caucasian patients aged 70-80 with Steady insulin
filtered_df = df[(df['race'] == 'Caucasian') & (df['age'] == '[70-80)') & (df['insulin'] == 'Steady')]

# Create a scatter plot
plt.scatter(filtered_df[filtered_df['gender'] == 'Male'].index,
            filtered_df[filtered_df['gender'] == 'Male']['time_in_hospital'],
            label='Male', color='blue')
plt.scatter(filtered_df[filtered_df['gender'] == 'Female'].index,
            filtered_df[filtered_df['gender'] == 'Female']['time_in_hospital'],
            label='Female', color='red')

plt.xlabel('Patient Index')
plt.ylabel('Time in Hospital')
plt.title('Scatter Plot of Caucasian Patients Aged 70-80 with Steady Insulin')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# Filter for Caucasian patients aged 70-80 with Steady insulin
filtered_df = df[(df['race'] == 'Caucasian') & (df['age'] == '[70-80)') & (df['insulin'] == 'Steady')]

# Create a table comparing the count of males and females
table = pd.pivot_table(filtered_df, values='encounter_id', index=['gender'], aggfunc='count')

# Create a bar chart
plt.figure(figsize=(8, 6))
plt.hist(table.index, table['encounter_id'])
plt.xlabel('Gender')
plt.ylabel('Number of Patients')
plt.title('Caucasian Patients Aged 70-80 with Steady Insulin')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6c061ede705f> in <cell line: 0>()
#      12 # Create a bar chart
#      13 plt.figure(figsize=(8, 6))
# ---> 14 plt.hist(table.index, table['encounter_id'])
#      15 plt.xlabel('Gender')
#      16 plt.ylabel('Number of Patients')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...
